# %%
An algorithm is a procedure used for solving a problem or performing a computation.
no numbers and underscore
 a mistake in aprogram or language where the syntax is correct,
but the meaning or logic is flawed, leading to an incorrect or nonsensical result.

the process of detecting and removing existing and potential errors (aka 'bugs’) from software code.
                        5 Python reserved words
                        1. if 
                        2. else
                        3. for
                        4. while
                        5. def

# %%
</ins>:
"Iesha"
"Pizza"
"Data Analyst"
