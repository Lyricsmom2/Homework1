# %% [markdown]
# # Homework 4
#
# 1. question 1
# 2. question 2

# %%
# Question 1 & Question 2
age=25

if age >= 25:
    print("Renting a car is more affordable")
elif 18 <=age < 25:
    print("Renting a car is very expensive")
else:
    print("You cannot legally rent a car")
# Out:
# Renting a car is more affordable

# %%
# Question 3

input_string = input("The quick brown fox jumps over the lazy dog")
vowels = "aeiouAEIOU"
vowel_count = 0

# %%
# Question 4
parnettone set={["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] and panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}
