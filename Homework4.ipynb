# %% [markdown]
# 1. To use a module, you must first import it into your program.
# 2. print, ref
# 3. A benefit of using Exception handling is preventing program crashes.
# 4. try, except, else, and finally.
# 5. Numpy arrays are like python lists.
# 6. One of the main benefits of using NumPy arrays is their performance and memory.
# 7. The main requirements about the 'dtype' of NumPy arrays must share the same data type.
# 8. np.zeros() and np.ones().
# 9. Pandas
# 10. Tuple
# 11. A tensor is a fundamental data structure representing a multi-dimensional array.
# 12. Numpy arrays store data of single, consistent type in congtiguous blocks of memory. (Fast memory access)
# 13. When creating an "empty" array, elements uses the indexer to specify the element and assign a vaule to it with the assignment operator.

# %%
#Create an if statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable", however if 'age' is less than 25, print "Renting a car is very expensive."
age = 30  # You can change this value to test different scenarios
if age >= 25:
    print("Renting a car is more affordable")
else:
    print("Renting a car is very expensive.")
# Out:
# Renting a car is more affordable

# %%
#Create and chain an if-else  statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable." If 'age' is less than 25 but greater than or equal to 18, print "Renting a car is very expensive." Finally, if age is less than 18, print "You cannot legally rent a car."
age = 20  # You can change this value to test different scenarios
if age >= 25:
    print("Renting a car is more affordable.")
elif age >= 18:
    print("Renting a car is very expensive.")
else:
    print("You cannot legally rent a car.")
# Out:
# Renting a car is very expensive.

# %%
#Loop over the following string to (1) count all the characters in the string and (2) print out all the vowels -- "The quick brown fox jumps over the lazy dog"
text = "The quick brown fox jumps over the lazy dog"
vowels = "aeiouAEIOU"
char_count = 0
vowel_list = []
for char in text:
    char_count += 1
    if char in vowels:
        vowel_list.append(char)
print(f"Total characters: {char_count}")
print(f"Vowels in the string: {vowel_list}")
# Out:
# Total characters: 43
# Vowels in the string: ['e', 'u', 'i', 'o', 'o', 'u', 'o', 'e', 'e', 'a', 'o']

# %%
# Write a nested loop that prints out every piece of clothing from the `couture` list, in every fashionable color from the `panettone` set: couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] and panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}
couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"]
panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}
for clothing in couture:
    for color in panettone:
        print(f"{color} {clothing}")
# Out:
# cerise trousers
# fuchsia trousers
# auburn trousers
# gunmetal blue trousers
# aqua trousers
# burnt sienna trousers
# Dark Sapphire trousers
# maple trousers
# cerise blouse
# fuchsia blouse
# auburn blouse
# gunmetal blue blouse
# aqua blouse
# burnt sienna blouse
# Dark Sapphire blouse
# maple blouse
# cerise bandana
# fuchsia bandana
# auburn bandana
# gunmetal blue bandana
# aqua bandana
# burnt sienna bandana
# Dark Sapphire bandana
# maple bandana
# cerise cumber band
# fuchsia cumber band
# auburn cumber band
# gunmetal blue cumber band
# aqua cumber band
# burnt sienna cumber band
# Dark Sapphire cumber band
# maple cumber band
# cerise blazer
# fuchsia blazer
# auburn blazer
# gunmetal blue blazer
# aqua blazer
# burnt sienna blazer
# Dark Sapphire blazer
# maple blazer
# cerise vest
# fuchsia vest
# auburn vest
# gunmetal blue vest
# aqua vest
# burnt sienna vest
# Dark Sapphire vest
# maple vest
# cerise french beret
# fuchsia french beret
# auburn french beret
# gunmetal blue french beret
# aqua french beret
# burnt sienna french beret
# Dark Sapphire french beret
# maple french beret
# cerise scarf
# fuchsia scarf
# auburn scarf
# gunmetal blue scarf
# aqua scarf
# burnt sienna scarf
# Dark Sapphire scarf
# maple scarf
# cerise stole
# fuchsia stole
# auburn stole
# gunmetal blue stole
# aqua stole
# burnt sienna stole
# Dark Sapphire stole
# maple stole

# %%
#Use range as a loop to calculate the sum of all the numbers from 1 to 100
total_sum = 0
for number in range(1, 101):
    total_sum += number
print(f"The sum of all numbers from 1 to 100 is: {total_sum}")
# Out:
# The sum of all numbers from 1 to 100 is: 5050

# %%
#Print the second item in this fruits list.
fruits = ["apple", "banana", "cherry"]
print(fruits[1])  # Output: banana
#Expected output:
    ['banana']
#Change the value from "apple" to "kiwi", in the fruits list.
    ["apple", "banana", "cherry"]
fruits[0] = "kiwi"
print(fruits)  # Output: ['kiwi', 'banana', 'cherry']
#Use the append method to add "orange" to the fruits list.
    ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)  # Output: ['apple', 'banana', 'cherry', '
orange']
#Use the insert method to add "lemon" as the second item in the fruits list.
    ["apple", "banana", "cherry"]
fruits.insert(1, "lemon")
print(fruits)  # Output: ['apple', 'lemon', 'banana', '
cherry']
#Use the remove method to remove "banana" from the fruits list.
    ["apple", "banana", "cherry"]
fruits.remove("banana")
print(fruits)  # Output: ['apple', 'cherry']
#Use negative indexing to print the 3rd and 2nd to last items in the list.
    ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruits[-3])  # Output: kiwi
print(fruits[-2])  # Output: melon
#Use a range of indexes to print the third, fourth, and fifth item in the list.
    ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruits[2:5])  # Output: ['cherry', 'orange', 'kiwi']
#Use the correct syntax to print the number of items in the list.
    ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(len(fruits))  # Output: 7
#Use the correct syntax to sort this list in reverse order
    ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits.sort(reverse=True)
print(fruits)  # Output: ['mango', 'melon', 'kiwi', 'orange', 'cherry', 'banana', 'apple']

# %%
#Use the DateTime module to get Current Date and Time, and save it to a variable. Then extract just the Full month name form that variable.
import datetime
now = datetime.datetime.now()
month_name = now.strftime("%B")
print(f"Current month name: {month_name}")
    #Write a simple function that takes 2 parameters -- a  first name and a day name.
def greet(first_name, day_name="Sunday"):
    print(f"Hi {first_name}! Happy {day_name}!")
#Set a default value for the day name of Sunday.
greet("Alice")
greet("Bob", "Monday")
greet("Alice", "Sunday")
greet("Bob", "Monday")
#Have the function print out a greeting -- using the parameters -- that says something like "Hi first-name! Happy day-name!". Remember to use the variables in the greeting to replace first-name and day-name. 
def greet(first_name, day_name="Sunday"):
    print(f"Hi {first_name}! Happy {day_name}!")
    #Invoke this function with 2 variables.
    #Write a block of code to handle one of the most common Python exception errors. Select one of the common errors from the curriculum section on Python Exception handling. Have your code example uses the `try`,`except`, `else`, and `finally` components.
